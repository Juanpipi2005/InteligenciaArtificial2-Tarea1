# %% [markdown]
# <a href="https://colab.research.google.com/github/Juanpipi2005/InteligenciaArtificial2-Tarea1/blob/main/PrimerTrabajoIA2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import matplotlib.pyplot as plt
import numpy as np
from prettytable import PrettyTable

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter


file_path = "Advertising.csv"

df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "brsahan/advertising-spend-vs-sales",
  file_path,
)

print("First 5 records:", df.head())
df.columns
# Out:
# /tmp/ipython-input-289/4121498648.py:9: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# Using Colab cache for faster access to the 'advertising-spend-vs-sales' dataset.
# First 5 records:       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9
# Index(['TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
df.columns
# Out:
# Index(['TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
# Ver columnas
print(df.columns)

# Suponiendo que Sales es el objetivo:
target_col = "Sales"

X = df.drop(columns=[target_col])
y = df[target_col]

n = X.shape[1]   # número de features
print("n features =", n)
# Out:
# Index(['TV', 'radio', 'newspaper', 'sales'], dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-289/3583844435.py in <cell line: 0>()
#       5 target_col = "Sales"
#       6
# ----> 7 X = df.drop(columns=[target_col])
#       8 y = df[target_col]
#       9
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# ...
